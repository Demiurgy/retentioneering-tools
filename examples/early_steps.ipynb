# %% [markdown]
# # First steps

# %%
from retentioneering import init_config
import pandas as pd

# %% [markdown]
# Firstly, we need to initialize our config file

# %%
init_config(
    experiments_folder='experiments', # folder for saving experiment results: graph visualization, heatmaps and etc.
    index_col='user_pseudo_id', # column by which we split users / sessions / whatever
    event_col='event_name', # column that describes event
    event_time_col='event_timestamp', # column that describes timestamp of event
    positive_target_event='passed', # name of positive target event
    negative_target_event='lost', # name of negative target event
    pos_target_definition={ # how to define positive event, e.g. empty means that add passed for whom was not 'lost'

    },
    neg_target_definition={ # how to define negative event, e.g. users who were inactive for 600 seconds.
        'time_limit': 600
    },
#     neg_target_definition={ # you also can define target event as list of other events
#         'event_list': ['lost']
#     }
)
# Out:
# /Users/anatolyzaytsev/.local/lib/python3.7/site-packages/retentioneering-0.4.1-py3.7.egg/retentioneering/core/utils.py:53: UserWarning: registration of accessor <class 'retentioneering.core.utils.init_config.<locals>.RetentioneeringTrajectory'> under name 'trajectory' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class RetentioneeringTrajectory(BaseTrajectory):
# /Users/anatolyzaytsev/.local/lib/python3.7/site-packages/retentioneering-0.4.1-py3.7.egg/retentioneering/core/utils.py:60: UserWarning: registration of accessor <class 'retentioneering.core.utils.init_config.<locals>.RetentioneeringDataset'> under name 'retention' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class RetentioneeringDataset(BaseDataset):

# %% [markdown]
# We need to create instance of pandas DataFrame with our data.

# %%
data = p

# %%
data = pd.read_csv('data/train.csv')
data = data.sort_values('event_timestamp')

# %%
data = data.retention.prepare()

# %%
data.head()
# Out:
#                               event_name      event_timestamp  \
# 13779          onboarding_welcome_screen  1538341204985002000
# 13780        onboarding__chooseLoginType  1538341208435003000
# 13781     onboarding_privacy_policyShown  1538341208468004000
# 13782             onboarding_login_Type1  1538341208478005000
# 13783  onboarding_privacy_policyAccepted  1538341211123008000
#
#                          user_pseudo_id
# 13779  3f711081df2e582efe4be33349b811ae
# 13780  3f711081df2e582efe4be33349b811ae
# 13781  3f711081df2e582efe4be33349b811ae
# 13782  3f711081df2e582efe4be33349b811ae
# 13783  3f711081df2e582efe4be33349b811ae

# %%
edgelist = data.retention.get_edgelist()
edgelist.head()
# Out:
#                     event_name                      next_event  event_count
# 0  onboarding__chooseLoginType                            lost     0.000242
# 1  onboarding__chooseLoginType          onboarding_login_Type1     0.100024
# 2  onboarding__chooseLoginType          onboarding_login_Type2     0.038415
# 3  onboarding__chooseLoginType  onboarding_privacy_policyShown     0.515342
# 4     onboarding__loginFailure                            lost     0.000242

# %% [markdown]
# You can use any columns as edge source and target using `cols` param, by default it is equal to list of `event_col` and automatically created `next_event` (shift of it) is used.
#
# Also you can use any column and any aggregation e.g.
# one can calculate number of unique users, who passed through edge via next chunk

# %%
data.head()
# Out:
#                         event_name      event_timestamp  \
# 30255    onboarding_welcome_screen  1538341610616002000
# 30256  onboarding_otherLogin__show  1538341616091017000
# 30257    onboarding_welcome_screen  1538341620614024000
# 30258    onboarding_welcome_screen  1538341626961003000
# 30259    onboarding_welcome_screen  1538341628689012000
#
#                          user_pseudo_id                   next_event  \
# 30255  000bf8e1812a0335c7e65d52b3f6e816  onboarding_otherLogin__show
# 30256  000bf8e1812a0335c7e65d52b3f6e816    onboarding_welcome_screen
# 30257  000bf8e1812a0335c7e65d52b3f6e816    onboarding_welcome_screen
# 30258  000bf8e1812a0335c7e65d52b3f6e816    onboarding_welcome_screen
# 30259  000bf8e1812a0335c7e65d52b3f6e816    onboarding_welcome_screen
#
#        next_timestamp
# 30255    1.538342e+18
# 30256    1.538342e+18
# 30257    1.538342e+18
# 30258    1.538342e+18
# 30259    1.538342e+18

# %%
edgelist = data.retention.get_edgelist(edge_col='user_pseudo_id', edge_attributes='users_nunique', norm=False)
edgelist.sort_values('users_nunique', ascending=False).head()
# Out:
#                         event_name                      next_event  \
# 84       onboarding_welcome_screen       onboarding_welcome_screen
# 85       onboarding_welcome_screen                          passed
# 3      onboarding__chooseLoginType  onboarding_privacy_policyShown
# 79       onboarding_welcome_screen     onboarding__chooseLoginType
# 67  onboarding_privacy_policyShown          onboarding_login_Type1
#
#     users_nunique
# 84           2586
# 85           2330
# 3            2112
# 79           1898
# 67           1667

# %% [markdown]
# or adjacency matrix

# %%
data.retention.get_adjacency()
# Out:
#                                              onboarding__chooseLoginType  \
# onboarding__chooseLoginType                                         0.00
# lost                                                                0.00
# onboarding_login_Type1                                              0.00
# onboarding_login_Type2                                              0.01
# onboarding_privacy_policyShown                                      0.00
# onboarding__loginFailure                                            0.00
# onboarding_login_Type1_cancel                                       0.05
# onboarding_welcome_screen                                           0.47
# onboarding_otherLogin__show                                         0.00
# onboarding_privacy_policyAccepted                                   0.03
# onboarding_privacy_policyDecline                                    0.01
# onboarding_privacy_policyTapToPolicy                                0.00
# onboarding_otherLogin__chooseLoginType                              0.00
# passed                                                              0.00
# onboarding_otherLogin_privacy_policyDecline                         0.00
# onboarding_otherLogin_privacy_policyShown                           0.00
# onboarding_profile_edit_close                                       0.01
# onboarding_otherLogin__close                                        0.06
#
#                                              lost  onboarding_login_Type1  \
# onboarding__chooseLoginType                  0.00                     0.1
# lost                                         0.00                     0.0
# onboarding_login_Type1                       0.01                     0.0
# onboarding_login_Type2                       0.01                     0.0
# onboarding_privacy_policyShown               0.00                     0.4
# onboarding__loginFailure                     0.00                     0.0
# onboarding_login_Type1_cancel                0.02                     0.0
# onboarding_welcome_screen                    0.25                     0.0
# onboarding_otherLogin__show                  0.02                     0.0
# onboarding_privacy_policyAccepted            0.04                     0.0
# onboarding_privacy_policyDecline             0.00                     0.0
# onboarding_privacy_policyTapToPolicy         0.00                     0.0
# onboarding_otherLogin__chooseLoginType       0.00                     0.0
# passed                                       0.00                     0.0
# onboarding_otherLogin_privacy_policyDecline  0.00                     0.0
# onboarding_otherLogin_privacy_policyShown    0.01                     0.0
# onboarding_profile_edit_close                0.00                     0.0
# onboarding_otherLogin__close                 0.02                     0.0
#
#                                              onboarding_login_Type2  \
# onboarding__chooseLoginType                                    0.04
# lost                                                           0.00
# onboarding_login_Type1                                         0.00
# onboarding_login_Type2                                         0.00
# onboarding_privacy_policyShown                                 0.11
# onboarding__loginFailure                                       0.00
# onboarding_login_Type1_cancel                                  0.00
# onboarding_welcome_screen                                      0.00
# onboarding_otherLogin__show                                    0.00
# onboarding_privacy_policyAccepted                              0.00
# onboarding_privacy_policyDecline                               0.00
# onboarding_privacy_policyTapToPolicy                           0.00
# onboarding_otherLogin__chooseLoginType                         0.00
# passed                                                         0.00
# onboarding_otherLogin_privacy_policyDecline                    0.00
# onboarding_otherLogin_privacy_policyShown                      0.00
# onboarding_profile_edit_close                                  0.00
# onboarding_otherLogin__close                                   0.00
#
#                                              onboarding_privacy_policyShown  \
# onboarding__chooseLoginType                                            0.52
# lost                                                                   0.00
# onboarding_login_Type1                                                 0.00
# onboarding_login_Type2                                                 0.00
# onboarding_privacy_policyShown                                         0.00
# onboarding__loginFailure                                               0.00
# onboarding_login_Type1_cancel                                          0.00
# onboarding_welcome_screen                                              0.00
# onboarding_otherLogin__show                                            0.00
# onboarding_privacy_policyAccepted                                      0.00
# onboarding_privacy_policyDecline                                       0.00
# onboarding_privacy_policyTapToPolicy                                   0.00
# onboarding_otherLogin__chooseLoginType                                 0.00
# passed                                                                 0.00
# onboarding_otherLogin_privacy_policyDecline                            0.00
# onboarding_otherLogin_privacy_policyShown                              0.00
# onboarding_profile_edit_close                                          0.00
# onboarding_otherLogin__close                                           0.00
#
#                                              onboarding__loginFailure  \
# onboarding__chooseLoginType                                      0.00
# lost                                                             0.00
# onboarding_login_Type1                                           0.03
# onboarding_login_Type2                                           0.00
# onboarding_privacy_policyShown                                   0.00
# onboarding__loginFailure                                         0.00
# onboarding_login_Type1_cancel                                    0.00
# onboarding_welcome_screen                                        0.00
# onboarding_otherLogin__show                                      0.00
# onboarding_privacy_policyAccepted                                0.10
# onboarding_privacy_policyDecline                                 0.00
# onboarding_privacy_policyTapToPolicy                             0.00
# onboarding_otherLogin__chooseLoginType                           0.00
# passed                                                           0.00
# onboarding_otherLogin_privacy_policyDecline                      0.00
# onboarding_otherLogin_privacy_policyShown                        0.00
# onboarding_profile_edit_close                                    0.00
# onboarding_otherLogin__close                                     0.00
#
#                                              onboarding_login_Type1_cancel  \
# onboarding__chooseLoginType                                           0.00
# lost                                                                  0.00
# onboarding_login_Type1                                                0.00
# onboarding_login_Type2                                                0.00
# onboarding_privacy_policyShown                                        0.00
# onboarding__loginFailure                                              0.12
# onboarding_login_Type1_cancel                                         0.00
# onboarding_welcome_screen                                             0.00
# onboarding_otherLogin__show                                           0.00
# onboarding_privacy_policyAccepted                                     0.00
# onboarding_privacy_policyDecline                                      0.00
# onboarding_privacy_policyTapToPolicy                                  0.00
# onboarding_otherLogin__chooseLoginType                                0.00
# passed                                                                0.00
# onboarding_otherLogin_privacy_policyDecline                           0.00
# onboarding_otherLogin_privacy_policyShown                             0.00
# onboarding_profile_edit_close                                         0.00
# onboarding_otherLogin__close                                          0.00
#
#                                              onboarding_welcome_screen  \
# onboarding__chooseLoginType                                       0.00
# lost                                                              0.00
# onboarding_login_Type1                                            0.04
# onboarding_login_Type2                                            0.00
# onboarding_privacy_policyShown                                    0.00
# onboarding__loginFailure                                          0.00
# onboarding_login_Type1_cancel                                     0.00
# onboarding_welcome_screen                                         1.21
# onboarding_otherLogin__show                                       0.21
# onboarding_privacy_policyAccepted                                 0.29
# onboarding_privacy_policyDecline                                  0.00
# onboarding_privacy_policyTapToPolicy                              0.00
# onboarding_otherLogin__chooseLoginType                            0.03
# passed                                                            0.00
# onboarding_otherLogin_privacy_policyDecline                       0.00
# onboarding_otherLogin_privacy_policyShown                         0.08
# onboarding_profile_edit_close                                     0.01
# onboarding_otherLogin__close                                      0.00
#
#                                              onboarding_otherLogin__show  \
# onboarding__chooseLoginType                                         0.00
# lost                                                                0.00
# onboarding_login_Type1                                              0.00
# onboarding_login_Type2                                              0.01
# onboarding_privacy_policyShown                                      0.00
# onboarding__loginFailure                                            0.00
# onboarding_login_Type1_cancel                                       0.04
# onboarding_welcome_screen                                           0.39
# onboarding_otherLogin__show                                         0.00
# onboarding_privacy_policyAccepted                                   0.02
# onboarding_privacy_policyDecline                                    0.01
# onboarding_privacy_policyTapToPolicy                                0.00
# onboarding_otherLogin__chooseLoginType                              0.00
# passed                                                              0.00
# onboarding_otherLogin_privacy_policyDecline                         0.00
# onboarding_otherLogin_privacy_policyShown                           0.00
# onboarding_profile_edit_close                                       0.01
# onboarding_otherLogin__close                                        0.03
#
#                                              onboarding_privacy_policyAccepted  \
# onboarding__chooseLoginType                                                0.0
# lost                                                                       0.0
# onboarding_login_Type1                                                     0.4
# onboarding_login_Type2                                                     0.1
# onboarding_privacy_policyShown                                             0.0
# onboarding__loginFailure                                                   0.0
# onboarding_login_Type1_cancel                                              0.0
# onboarding_welcome_screen                                                  0.0
# onboarding_otherLogin__show                                                0.0
# onboarding_privacy_policyAccepted                                          0.0
# onboarding_privacy_policyDecline                                           0.0
# onboarding_privacy_policyTapToPolicy                                       0.0
# onboarding_otherLogin__chooseLoginType                                     0.0
# passed                                                                     0.0
# onboarding_otherLogin_privacy_policyDecline                                0.0
# onboarding_otherLogin_privacy_policyShown                                  0.0
# onboarding_profile_edit_close                                              0.0
# onboarding_otherLogin__close                                               0.0
#
#                                              onboarding_privacy_policyDecline  \
# onboarding__chooseLoginType                                              0.00
# lost                                                                     0.00
# onboarding_login_Type1                                                   0.01
# onboarding_login_Type2                                                   0.01
# onboarding_privacy_policyShown                                           0.00
# onboarding__loginFailure                                                 0.00
# onboarding_login_Type1_cancel                                            0.00
# onboarding_welcome_screen                                                0.00
# onboarding_otherLogin__show                                              0.00
# onboarding_privacy_policyAccepted                                        0.00
# onboarding_privacy_policyDecline                                         0.00
# onboarding_privacy_policyTapToPolicy                                     0.00
# onboarding_otherLogin__chooseLoginType                                   0.00
# passed                                                                   0.00
# onboarding_otherLogin_privacy_policyDecline                              0.00
# onboarding_otherLogin_privacy_policyShown                                0.00
# onboarding_profile_edit_close                                            0.00
# onboarding_otherLogin__close                                             0.00
#
#                                              onboarding_privacy_policyTapToPolicy  \
# onboarding__chooseLoginType                                                   0.0
# lost                                                                          0.0
# onboarding_login_Type1                                                        0.0
# onboarding_login_Type2                                                        0.0
# onboarding_privacy_policyShown                                                0.0
# onboarding__loginFailure                                                      0.0
# onboarding_login_Type1_cancel                                                 0.0
# onboarding_welcome_screen                                                     0.0
# onboarding_otherLogin__show                                                   0.0
# onboarding_privacy_policyAccepted                                             0.0
# onboarding_privacy_policyDecline                                              0.0
# onboarding_privacy_policyTapToPolicy                                          0.0
# onboarding_otherLogin__chooseLoginType                                        0.0
# passed                                                                        0.0
# onboarding_otherLogin_privacy_policyDecline                                   0.0
# onboarding_otherLogin_privacy_policyShown                                     0.0
# onboarding_profile_edit_close                                                 0.0
# onboarding_otherLogin__close                                                  0.0
#
#                                              onboarding_otherLogin__chooseLoginType  \
# onboarding__chooseLoginType                                                    0.00
# lost                                                                           0.00
# onboarding_login_Type1                                                         0.00
# onboarding_login_Type2                                                         0.00
# onboarding_privacy_policyShown                                                 0.00
# onboarding__loginFailure                                                       0.00
# onboarding_login_Type1_cancel                                                  0.00
# onboarding_welcome_screen                                                      0.00
# onboarding_otherLogin__show                                                    0.17
# onboarding_privacy_policyAccepted                                              0.00
# onboarding_privacy_policyDecline                                               0.00
# onboarding_privacy_policyTapToPolicy                                           0.00
# onboarding_otherLogin__chooseLoginType                                         0.00
# passed                                                                         0.00
# onboarding_otherLogin_privacy_policyDecline                                    0.00
# onboarding_otherLogin_privacy_policyShown                                      0.00
# onboarding_profile_edit_close                                                  0.00
# onboarding_otherLogin__close                                                   0.00
#
#                                              passed  \
# onboarding__chooseLoginType                    0.00
# lost                                           0.00
# onboarding_login_Type1                         0.00
# onboarding_login_Type2                         0.01
# onboarding_privacy_policyShown                 0.00
# onboarding__loginFailure                       0.00
# onboarding_login_Type1_cancel                  0.00
# onboarding_welcome_screen                      0.56
# onboarding_otherLogin__show                    0.00
# onboarding_privacy_policyAccepted              0.03
# onboarding_privacy_policyDecline               0.00
# onboarding_privacy_policyTapToPolicy           0.00
# onboarding_otherLogin__chooseLoginType         0.00
# passed                                         0.00
# onboarding_otherLogin_privacy_policyDecline    0.00
# onboarding_otherLogin_privacy_policyShown      0.00
# onboarding_profile_edit_close                  0.00
# onboarding_otherLogin__close                   0.00
#
#                                              onboarding_otherLogin_privacy_policyDecline  \
# onboarding__chooseLoginType                                                         0.00
# lost                                                                                0.00
# onboarding_login_Type1                                                              0.00
# onboarding_login_Type2                                                              0.00
# onboarding_privacy_policyShown                                                      0.00
# onboarding__loginFailure                                                            0.00
# onboarding_login_Type1_cancel                                                       0.00
# onboarding_welcome_screen                                                           0.00
# onboarding_otherLogin__show                                                         0.00
# onboarding_privacy_policyAccepted                                                   0.00
# onboarding_privacy_policyDecline                                                    0.00
# onboarding_privacy_policyTapToPolicy                                                0.00
# onboarding_otherLogin__chooseLoginType                                              0.00
# passed                                                                              0.00
# onboarding_otherLogin_privacy_policyDecline                                         0.00
# onboarding_otherLogin_privacy_policyShown                                           0.01
# onboarding_profile_edit_close                                                       0.00
# onboarding_otherLogin__close                                                        0.00
#
#                                              onboarding_otherLogin_privacy_policyShown  \
# onboarding__chooseLoginType                                                       0.00
# lost                                                                              0.00
# onboarding_login_Type1                                                            0.00
# onboarding_login_Type2                                                            0.00
# onboarding_privacy_policyShown                                                    0.00
# onboarding__loginFailure                                                          0.00
# onboarding_login_Type1_cancel                                                     0.00
# onboarding_welcome_screen                                                         0.00
# onboarding_otherLogin__show                                                       0.00
# onboarding_privacy_policyAccepted                                                 0.00
# onboarding_privacy_policyDecline                                                  0.00
# onboarding_privacy_policyTapToPolicy                                              0.00
# onboarding_otherLogin__chooseLoginType                                            0.12
# passed                                                                            0.00
# onboarding_otherLogin_privacy_policyDecline                                       0.00
# onboarding_otherLogin_privacy_policyShown                                         0.00
# onboarding_profile_edit_close                                                     0.00
# onboarding_otherLogin__close                                                      0.00
#
#                                              onboarding_profile_edit_close  \
# onboarding__chooseLoginType                                           0.00
# lost                                                                  0.00
# onboarding_login_Type1                                                0.00
# onboarding_login_Type2                                                0.00
# onboarding_privacy_policyShown                                        0.00
# onboarding__loginFailure                                              0.00
# onboarding_login_Type1_cancel                                         0.00
# onboarding_welcome_screen                                             0.00
# onboarding_otherLogin__show                                           0.00
# onboarding_privacy_policyAccepted                                     0.00
# onboarding_privacy_policyDecline                                      0.00
# onboarding_privacy_policyTapToPolicy                                  0.00
# onboarding_otherLogin__chooseLoginType                                0.01
# passed                                                                0.00
# onboarding_otherLogin_privacy_policyDecline                           0.00
# onboarding_otherLogin_privacy_policyShown                             0.02
# onboarding_profile_edit_close                                         0.00
# onboarding_otherLogin__close                                          0.00
#
#                                              onboarding_otherLogin__close
# onboarding__chooseLoginType                                          0.00
# lost                                                                 0.00
# onboarding_login_Type1                                               0.00
# onboarding_login_Type2                                               0.00
# onboarding_privacy_policyShown                                       0.00
# onboarding__loginFailure                                             0.00
# onboarding_login_Type1_cancel                                        0.00
# onboarding_welcome_screen                                            0.00
# onboarding_otherLogin__show                                          0.12
# onboarding_privacy_policyAccepted                                    0.00
# onboarding_privacy_policyDecline                                     0.00
# onboarding_privacy_policyTapToPolicy                                 0.00
# onboarding_otherLogin__chooseLoginType                               0.00
# passed                                                               0.00
# onboarding_otherLogin_privacy_policyDecline                          0.00
# onboarding_otherLogin_privacy_policyShown                            0.00
# onboarding_profile_edit_close                                        0.00
# onboarding_otherLogin__close                                         0.00

# %% [markdown]
# All similar parameters work for adjacency matrix calculation.

# %%
data.retention.get_adjacency(edge_col='user_pseudo_id', edge_attributes='users_nunique', norm=False)
# Out:
#                                              onboarding__chooseLoginType  \
# onboarding__chooseLoginType                                          0.0
# lost                                                                 0.0
# onboarding_login_Type1                                              12.0
# onboarding_login_Type2                                              34.0
# onboarding_privacy_policyShown                                       0.0
# onboarding__loginFailure                                             0.0
# onboarding_login_Type1_cancel                                      200.0
# onboarding_welcome_screen                                         1898.0
# onboarding_otherLogin__show                                          0.0
# onboarding_privacy_policyAccepted                                  127.0
# onboarding_privacy_policyDecline                                    46.0
# onboarding_privacy_policyTapToPolicy                                 1.0
# onboarding_otherLogin__chooseLoginType                               3.0
# passed                                                               0.0
# onboarding_otherLogin_privacy_policyDecline                         11.0
# onboarding_otherLogin_privacy_policyShown                            9.0
# onboarding_profile_edit_close                                       34.0
# onboarding_otherLogin__close                                       249.0
#
#                                                lost  onboarding_login_Type1  \
# onboarding__chooseLoginType                     1.0                   356.0
# lost                                            0.0                     0.0
# onboarding_login_Type1                         40.0                     0.0
# onboarding_login_Type2                         32.0                     0.0
# onboarding_privacy_policyShown                  0.0                  1667.0
# onboarding__loginFailure                        1.0                     0.0
# onboarding_login_Type1_cancel                  91.0                     0.0
# onboarding_welcome_screen                    1043.0                     0.0
# onboarding_otherLogin__show                    82.0                     0.0
# onboarding_privacy_policyAccepted             161.0                     0.0
# onboarding_privacy_policyDecline               17.0                     0.0
# onboarding_privacy_policyTapToPolicy            7.0                     0.0
# onboarding_otherLogin__chooseLoginType         12.0                     0.0
# passed                                          0.0                     0.0
# onboarding_otherLogin_privacy_policyDecline     4.0                     0.0
# onboarding_otherLogin_privacy_policyShown      33.0                     0.0
# onboarding_profile_edit_close                  19.0                     0.0
# onboarding_otherLogin__close                   99.0                     0.0
#
#                                              onboarding_login_Type2  \
# onboarding__chooseLoginType                                   142.0
# lost                                                            0.0
# onboarding_login_Type1                                          0.0
# onboarding_login_Type2                                          0.0
# onboarding_privacy_policyShown                                455.0
# onboarding__loginFailure                                        0.0
# onboarding_login_Type1_cancel                                   0.0
# onboarding_welcome_screen                                       0.0
# onboarding_otherLogin__show                                     0.0
# onboarding_privacy_policyAccepted                               0.0
# onboarding_privacy_policyDecline                                0.0
# onboarding_privacy_policyTapToPolicy                            0.0
# onboarding_otherLogin__chooseLoginType                          0.0
# passed                                                          0.0
# onboarding_otherLogin_privacy_policyDecline                     0.0
# onboarding_otherLogin_privacy_policyShown                       0.0
# onboarding_profile_edit_close                                   0.0
# onboarding_otherLogin__close                                    0.0
#
#                                              onboarding_privacy_policyShown  \
# onboarding__chooseLoginType                                          2112.0
# lost                                                                    0.0
# onboarding_login_Type1                                                  0.0
# onboarding_login_Type2                                                  0.0
# onboarding_privacy_policyShown                                          0.0
# onboarding__loginFailure                                                0.0
# onboarding_login_Type1_cancel                                           0.0
# onboarding_welcome_screen                                               0.0
# onboarding_otherLogin__show                                             0.0
# onboarding_privacy_policyAccepted                                       0.0
# onboarding_privacy_policyDecline                                        0.0
# onboarding_privacy_policyTapToPolicy                                    0.0
# onboarding_otherLogin__chooseLoginType                                  0.0
# passed                                                                  0.0
# onboarding_otherLogin_privacy_policyDecline                             0.0
# onboarding_otherLogin_privacy_policyShown                               0.0
# onboarding_profile_edit_close                                           0.0
# onboarding_otherLogin__close                                            0.0
#
#                                              onboarding__loginFailure  \
# onboarding__chooseLoginType                                       0.0
# lost                                                              0.0
# onboarding_login_Type1                                          104.0
# onboarding_login_Type2                                            5.0
# onboarding_privacy_policyShown                                    0.0
# onboarding__loginFailure                                          0.0
# onboarding_login_Type1_cancel                                     0.0
# onboarding_welcome_screen                                         4.0
# onboarding_otherLogin__show                                       1.0
# onboarding_privacy_policyAccepted                               402.0
# onboarding_privacy_policyDecline                                  0.0
# onboarding_privacy_policyTapToPolicy                              0.0
# onboarding_otherLogin__chooseLoginType                            0.0
# passed                                                            0.0
# onboarding_otherLogin_privacy_policyDecline                       0.0
# onboarding_otherLogin_privacy_policyShown                         0.0
# onboarding_profile_edit_close                                     0.0
# onboarding_otherLogin__close                                      0.0
#
#                                              onboarding_login_Type1_cancel  \
# onboarding__chooseLoginType                                            0.0
# lost                                                                   0.0
# onboarding_login_Type1                                                 0.0
# onboarding_login_Type2                                                 0.0
# onboarding_privacy_policyShown                                         0.0
# onboarding__loginFailure                                             457.0
# onboarding_login_Type1_cancel                                          0.0
# onboarding_welcome_screen                                              0.0
# onboarding_otherLogin__show                                            0.0
# onboarding_privacy_policyAccepted                                      0.0
# onboarding_privacy_policyDecline                                       0.0
# onboarding_privacy_policyTapToPolicy                                   0.0
# onboarding_otherLogin__chooseLoginType                                 0.0
# passed                                                                 0.0
# onboarding_otherLogin_privacy_policyDecline                            0.0
# onboarding_otherLogin_privacy_policyShown                              0.0
# onboarding_profile_edit_close                                          0.0
# onboarding_otherLogin__close                                           0.0
#
#                                              onboarding_welcome_screen  \
# onboarding__chooseLoginType                                        0.0
# lost                                                               0.0
# onboarding_login_Type1                                           180.0
# onboarding_login_Type2                                             4.0
# onboarding_privacy_policyShown                                     0.0
# onboarding__loginFailure                                          18.0
# onboarding_login_Type1_cancel                                     14.0
# onboarding_welcome_screen                                       2586.0
# onboarding_otherLogin__show                                      873.0
# onboarding_privacy_policyAccepted                               1187.0
# onboarding_privacy_policyDecline                                   0.0
# onboarding_privacy_policyTapToPolicy                               0.0
# onboarding_otherLogin__chooseLoginType                           136.0
# passed                                                             0.0
# onboarding_otherLogin_privacy_policyDecline                        0.0
# onboarding_otherLogin_privacy_policyShown                        339.0
# onboarding_profile_edit_close                                     42.0
# onboarding_otherLogin__close                                      11.0
#
#                                              onboarding_otherLogin__show  \
# onboarding__chooseLoginType                                          0.0
# lost                                                                 0.0
# onboarding_login_Type1                                              10.0
# onboarding_login_Type2                                              44.0
# onboarding_privacy_policyShown                                       0.0
# onboarding__loginFailure                                             0.0
# onboarding_login_Type1_cancel                                      181.0
# onboarding_welcome_screen                                         1581.0
# onboarding_otherLogin__show                                          2.0
# onboarding_privacy_policyAccepted                                   81.0
# onboarding_privacy_policyDecline                                    38.0
# onboarding_privacy_policyTapToPolicy                                 0.0
# onboarding_otherLogin__chooseLoginType                               9.0
# passed                                                               0.0
# onboarding_otherLogin_privacy_policyDecline                         14.0
# onboarding_otherLogin_privacy_policyShown                           18.0
# onboarding_profile_edit_close                                       40.0
# onboarding_otherLogin__close                                       120.0
#
#                                              onboarding_privacy_policyAccepted  \
# onboarding__chooseLoginType                                                0.0
# lost                                                                       0.0
# onboarding_login_Type1                                                  1639.0
# onboarding_login_Type2                                                   405.0
# onboarding_privacy_policyShown                                             0.0
# onboarding__loginFailure                                                   0.0
# onboarding_login_Type1_cancel                                              0.0
# onboarding_welcome_screen                                                  0.0
# onboarding_otherLogin__show                                                0.0
# onboarding_privacy_policyAccepted                                          0.0
# onboarding_privacy_policyDecline                                           0.0
# onboarding_privacy_policyTapToPolicy                                      10.0
# onboarding_otherLogin__chooseLoginType                                     0.0
# passed                                                                     0.0
# onboarding_otherLogin_privacy_policyDecline                                0.0
# onboarding_otherLogin_privacy_policyShown                                  0.0
# onboarding_profile_edit_close                                              0.0
# onboarding_otherLogin__close                                               0.0
#
#                                              onboarding_privacy_policyDecline  \
# onboarding__chooseLoginType                                               0.0
# lost                                                                      0.0
# onboarding_login_Type1                                                   43.0
# onboarding_login_Type2                                                   54.0
# onboarding_privacy_policyShown                                            0.0
# onboarding__loginFailure                                                  0.0
# onboarding_login_Type1_cancel                                             0.0
# onboarding_welcome_screen                                                 0.0
# onboarding_otherLogin__show                                               0.0
# onboarding_privacy_policyAccepted                                         0.0
# onboarding_privacy_policyDecline                                          0.0
# onboarding_privacy_policyTapToPolicy                                      4.0
# onboarding_otherLogin__chooseLoginType                                    0.0
# passed                                                                    0.0
# onboarding_otherLogin_privacy_policyDecline                               0.0
# onboarding_otherLogin_privacy_policyShown                                 0.0
# onboarding_profile_edit_close                                             0.0
# onboarding_otherLogin__close                                              0.0
#
#                                              onboarding_privacy_policyTapToPolicy  \
# onboarding__chooseLoginType                                                   0.0
# lost                                                                          0.0
# onboarding_login_Type1                                                       17.0
# onboarding_login_Type2                                                        5.0
# onboarding_privacy_policyShown                                                0.0
# onboarding__loginFailure                                                      0.0
# onboarding_login_Type1_cancel                                                 0.0
# onboarding_welcome_screen                                                     0.0
# onboarding_otherLogin__show                                                   0.0
# onboarding_privacy_policyAccepted                                             0.0
# onboarding_privacy_policyDecline                                              0.0
# onboarding_privacy_policyTapToPolicy                                          0.0
# onboarding_otherLogin__chooseLoginType                                        0.0
# passed                                                                        0.0
# onboarding_otherLogin_privacy_policyDecline                                   0.0
# onboarding_otherLogin_privacy_policyShown                                     0.0
# onboarding_profile_edit_close                                                 0.0
# onboarding_otherLogin__close                                                  0.0
#
#                                              onboarding_otherLogin__chooseLoginType  \
# onboarding__chooseLoginType                                                     0.0
# lost                                                                            0.0
# onboarding_login_Type1                                                          0.0
# onboarding_login_Type2                                                          0.0
# onboarding_privacy_policyShown                                                  0.0
# onboarding__loginFailure                                                        0.0
# onboarding_login_Type1_cancel                                                   1.0
# onboarding_welcome_screen                                                       0.0
# onboarding_otherLogin__show                                                   644.0
# onboarding_privacy_policyAccepted                                               0.0
# onboarding_privacy_policyDecline                                                0.0
# onboarding_privacy_policyTapToPolicy                                            0.0
# onboarding_otherLogin__chooseLoginType                                          0.0
# passed                                                                          0.0
# onboarding_otherLogin_privacy_policyDecline                                     0.0
# onboarding_otherLogin_privacy_policyShown                                       0.0
# onboarding_profile_edit_close                                                   0.0
# onboarding_otherLogin__close                                                    0.0
#
#                                              passed  \
# onboarding__chooseLoginType                     0.0
# lost                                            0.0
# onboarding_login_Type1                          0.0
# onboarding_login_Type2                         22.0
# onboarding_privacy_policyShown                  0.0
# onboarding__loginFailure                        0.0
# onboarding_login_Type1_cancel                   0.0
# onboarding_welcome_screen                    2330.0
# onboarding_otherLogin__show                     2.0
# onboarding_privacy_policyAccepted             121.0
# onboarding_privacy_policyDecline                0.0
# onboarding_privacy_policyTapToPolicy            0.0
# onboarding_otherLogin__chooseLoginType          1.0
# passed                                          0.0
# onboarding_otherLogin_privacy_policyDecline     0.0
# onboarding_otherLogin_privacy_policyShown       0.0
# onboarding_profile_edit_close                   1.0
# onboarding_otherLogin__close                    1.0
#
#                                              onboarding_otherLogin_privacy_policyDecline  \
# onboarding__chooseLoginType                                                          0.0
# lost                                                                                 0.0
# onboarding_login_Type1                                                               0.0
# onboarding_login_Type2                                                               0.0
# onboarding_privacy_policyShown                                                       0.0
# onboarding__loginFailure                                                             0.0
# onboarding_login_Type1_cancel                                                        0.0
# onboarding_welcome_screen                                                            0.0
# onboarding_otherLogin__show                                                          0.0
# onboarding_privacy_policyAccepted                                                    0.0
# onboarding_privacy_policyDecline                                                     0.0
# onboarding_privacy_policyTapToPolicy                                                 0.0
# onboarding_otherLogin__chooseLoginType                                               5.0
# passed                                                                               0.0
# onboarding_otherLogin_privacy_policyDecline                                          0.0
# onboarding_otherLogin_privacy_policyShown                                           24.0
# onboarding_profile_edit_close                                                        0.0
# onboarding_otherLogin__close                                                         0.0
#
#                                              onboarding_otherLogin_privacy_policyShown  \
# onboarding__chooseLoginType                                                        0.0
# lost                                                                               0.0
# onboarding_login_Type1                                                             0.0
# onboarding_login_Type2                                                             0.0
# onboarding_privacy_policyShown                                                     0.0
# onboarding__loginFailure                                                           0.0
# onboarding_login_Type1_cancel                                                      0.0
# onboarding_welcome_screen                                                          0.0
# onboarding_otherLogin__show                                                        0.0
# onboarding_privacy_policyAccepted                                                  0.0
# onboarding_privacy_policyDecline                                                   0.0
# onboarding_privacy_policyTapToPolicy                                               0.0
# onboarding_otherLogin__chooseLoginType                                           501.0
# passed                                                                             0.0
# onboarding_otherLogin_privacy_policyDecline                                        0.0
# onboarding_otherLogin_privacy_policyShown                                          0.0
# onboarding_profile_edit_close                                                      0.0
# onboarding_otherLogin__close                                                       0.0
#
#                                              onboarding_profile_edit_close  \
# onboarding__chooseLoginType                                            0.0
# lost                                                                   0.0
# onboarding_login_Type1                                                 0.0
# onboarding_login_Type2                                                 0.0
# onboarding_privacy_policyShown                                         0.0
# onboarding__loginFailure                                               0.0
# onboarding_login_Type1_cancel                                          0.0
# onboarding_welcome_screen                                             16.0
# onboarding_otherLogin__show                                            0.0
# onboarding_privacy_policyAccepted                                      0.0
# onboarding_privacy_policyDecline                                       0.0
# onboarding_privacy_policyTapToPolicy                                   0.0
# onboarding_otherLogin__chooseLoginType                                41.0
# passed                                                                 0.0
# onboarding_otherLogin_privacy_policyDecline                            0.0
# onboarding_otherLogin_privacy_policyShown                             80.0
# onboarding_profile_edit_close                                          0.0
# onboarding_otherLogin__close                                           0.0
#
#                                              onboarding_otherLogin__close
# onboarding__chooseLoginType                                           0.0
# lost                                                                  0.0
# onboarding_login_Type1                                                0.0
# onboarding_login_Type2                                                0.0
# onboarding_privacy_policyShown                                        0.0
# onboarding__loginFailure                                              0.0
# onboarding_login_Type1_cancel                                         0.0
# onboarding_welcome_screen                                             3.0
# onboarding_otherLogin__show                                         445.0
# onboarding_privacy_policyAccepted                                     0.0
# onboarding_privacy_policyDecline                                      0.0
# onboarding_privacy_policyTapToPolicy                                  0.0
# onboarding_otherLogin__chooseLoginType                                0.0
# passed                                                                0.0
# onboarding_otherLogin_privacy_policyDecline                           0.0
# onboarding_otherLogin_privacy_policyShown                             0.0
# onboarding_profile_edit_close                                         0.0
# onboarding_otherLogin__close                                          0.0

# %% [markdown]
# or we can simply visualize graph.
#
# By default weight in visualization is equal to rate of unique users, who pass the edge,
# you can change it to rate of all event occasions by turning `user_based` equal `False`.

# %%
data.retention.plot_graph(thresh=0.05, width=800, height=800)
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/layout.py:923: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_27_42_014865.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# If you change node positions and want to save resulting layout, you can click on donwload button and load it to graph visualizer as follows.

# %%
data.retention.plot_graph(layout_dump='node_params.json', width=800, height=800)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_27_45_083119.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Also you can use other data columns and aggregation functions from `retention.get_edgelist()` method (be sure that in this case `user_based=False`).
#
# For example, we can visualize mean time between events.
#
# Firtly, we should add column with time difference between event timestamps.

# %%
data['seconds_between_events'] = (data.next_timestamp - data.event_timestamp) * 1e-9
# use show_percent=False to visualize absolute value
data.retention.plot_graph(user_based=False, edge_col='seconds_between_events', edge_attributes='time_mean', thresh=0.01, width=800, height=800, show_percent=False)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_27_46_481546.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Temporal funnel

# %% [markdown]
# Let's plot the temporal funnel. Rows correspond to different events and columns correspond to step number in the user trajectory, value corresponds to fraction of all users who had corresponding event at corresponding step. For example, you can see that all users in the analysis start from "welcome_screen" (step 1) and end ended up passed (~0.6) or lost (~0.4) after 24 steps

# %%
desc_table = data.retention.get_step_matrix(max_steps=30)

# %% [markdown]
# And we can calculate temporal funnel difference between two groups

# %%
# create group filter based on target events
diff_filter = data.retention.create_filter()

# calculate difference table between two groups
diff_table = data.retention.get_step_matrix_difference(diff_filter, max_steps=30)

# %% [markdown]
# # Clustering

# %% [markdown]
# We can use clustering with different visualizations

# %% [markdown]
# Clutermap allows to see how important different events are for clustering.
# For example we can see that `onboarding_welcome_screen` is always equal, so it does not affect clustering, but `onboarding_chooseLoginType` varies accross users and creates some clusters.

# %%
data.retention.get_clusters(plot_type='cluster_heatmap');

# %% [markdown]
# Then it will be useful to visualize projection of user trajectories to understand how many clusters we have.

# %%
data.retention.learn_tsne(plot_type='targets');

# %% [markdown]
# We can see that projection is poor, so it will be good to tune it. To update TSNE weights we need to set `refit` parameter to `True`.
#
# Any parameter from `sklearn.manifold.TSNE` can be used, e.g. `perplexity` can help to obtain better visualization.

# %%
data.retention.learn_tsne(perplexity=10, plot_type='targets', refit=True);

# %% [markdown]
# Now we can see two dense cirle clusters.
#
# Any parameters from `sklearn.cluster.KMeans` can be used.

# %%
data.retention.get_clusters(n_clusters=8, plot_type='cluster_tsne', refit_cluster=True);

# %% [markdown]
# We do not use target events in clustering, so we can compare different groups in terms of what target event is likely to occur in them.

# %%
data.retention.get_clusters(plot_type='cluster_pie');

# %% [markdown]
# We can see that clusters `0` and `1` are pretty interesting, so we can visualize graph for them.

# %%
(data
 .retention
 .filter_cluster(0)
 .retention
 .plot_graph(width=800, height=800))
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/layout.py:923: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 15_57_22_147199.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
(data
 .retention
 .filter_cluster(1)
 .retention
 .plot_graph(width=800, height=800))
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_29_23_519038.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
(data
 .retention
 .filter_cluster(4)
 .retention
 .plot_graph(width=800, height=800))
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_34_04_707943.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
(data
 .retention
 .filter_cluster(5)
 .retention
 .plot_graph(width=800, height=800))
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_29_50_165605.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
(data
 .retention
 .filter_cluster(7)
 .retention
 .plot_graph(width=800, height=800))
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-28 12_31_16_178157.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Supervised classifier

# %% [markdown]
# Supervised learning is usually better then clustering.

# %%
model = data.retention.create_model()
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# To understand what features are meaningful, we can visualize graph of weights.
#
# Larger the node or edge, larger its effect on probability of target event.
# Green nodes mean positive effect, red nodes -- negative.

# %%
features = data.retention.extract_features(ngram_range=(1,2))
target = features.index.isin(data.retention.get_positive_users())

# %%
model.permutation_importance(features, target, thresh=0.)
# Out:
#             ROC-AUC: 0.9124591164734438
#             PR-AUC: 0.8975341600045529
#             Accuracy: 0.8849514563106796
# /Users/anatolyzaytsev/.local/lib/python3.7/site-packages/retentioneering-0.4.1-py3.7.egg/retentioneering/visualization/plot.py:291: RuntimeWarning: divide by zero encountered in log1p
#   "weight": np.log1p(row.weight_norm) * 1.5,
#         <iframe
#             width="600"
#             height="600"
#             src="experiments/index_2019-06-23 18_43_48_838786.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# You can use any different model with sklearn-api (ont only sklearn package has it e.g. `lightgm` can be used too).
#
# And pass params to it.

# %%
from sklearn.ensemble import RandomForestClassifier
model = data.retention.create_model(RandomForestClassifier, n_estimators=25)

# %%
features = data.retention.extract_features(ngram_range=(1,2))
target = features.index.isin(data.retention.get_positive_users())

# %%
model.permutation_importance(features, target, thresh=0.)
# Out:
#             ROC-AUC: 0.9592964985907655
#             PR-AUC: 0.9456069017198432
#             Accuracy: 0.9269417475728156
#         <iframe
#             width="600"
#             height="600"
#             src="experiments/index_2019-06-23 18_44_00_650162.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
