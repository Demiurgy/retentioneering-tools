# %%
# !pip  install sshtunnel
# !pip install psycopg2 sqlalchemy
# Out:
# Collecting sshtunnel
#   Downloading https://files.pythonhosted.org/packages/c5/5c/4b320d7ec4b0d5d4d6df1fdf66a5799625b3623d0ce4efe81719c6f8dfb3/sshtunnel-0.1.5.tar.gz (49kB)
#      |████████████████████████████████| 51kB 1.5MB/s
# Collecting paramiko>=1.15.2 (from sshtunnel)
#   Downloading https://files.pythonhosted.org/packages/4b/80/74dace9e48b0ef923633dfb5e48798f58a168e4734bca8ecfaf839ba051a/paramiko-2.6.0-py2.py3-none-any.whl (199kB)
#      |████████████████████████████████| 204kB 13.9MB/s
# Collecting cryptography>=2.5 (from paramiko>=1.15.2->sshtunnel)
#   Downloading https://files.pythonhosted.org/packages/97/18/c6557f63a6abde34707196fb2cad1c6dc0dbff25a200d5044922496668a4/cryptography-2.7-cp34-abi3-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 42.1MB/s
# Collecting pynacl>=1.0.1 (from paramiko>=1.15.2->sshtunnel)
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
#      |████████████████████████████████| 768kB 44.5MB/s
# Collecting bcrypt>=3.1.3 (from paramiko>=1.15.2->sshtunnel)
#   Downloading https://files.pythonhosted.org/packages/8b/1d/82826443777dd4a624e38a08957b975e75df859b381ae302cfd7a30783ed/bcrypt-3.1.7-cp34-abi3-manylinux1_x86_64.whl (56kB)
#      |████████████████████████████████| 61kB 18.6MB/s
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.5->paramiko>=1.15.2->sshtunnel) (1.12.3)
# Collecting asn1crypto>=0.21.0 (from cryptography>=2.5->paramiko>=1.15.2->sshtunnel)
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 28.6MB/s
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.5->paramiko>=1.15.2->sshtunnel) (1.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.5->paramiko>=1.15.2->sshtunnel) (2.19)
# Building wheels for collected packages: sshtunnel
#   Building wheel for sshtunnel (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/e8/d2/38/b9791b7391f634099194ec6697fa671194f3353906d94c8f92
# Successfully built sshtunnel
# Installing collected packages: asn1crypto, cryptography, pynacl, bcrypt, paramiko, sshtunnel
# Successfully installed asn1crypto-0.24.0 bcrypt-3.1.7 cryptography-2.7 paramiko-2.6.0 pynacl-1.3.0 sshtunnel-0.1.5
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.6/dist-packages (2.7.6.1)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.6/dist-packages (1.3.5)

# %%
import psycopg2
import requests
import pandas as pd

# %%
import sqlalchemy as db
engine = db.create_engine('postgresql://postgres:postgres@176.112.192.94:5432/reboard-api')

# %%
query = """
select ge_timestamp_event as event_timestamp , ge_session_id as user_pseudo_id, ge_event_name as event_name from pixel.game_event
"""

# %%
result = pd.read_sql(query, engine)
result
# Out:
#         event_timestamp   user_pseudo_id                   event_name
# 0   2019-06-29 16:12:29  1561816724099|1  tech_screen_change_mainmenu
# 1   2019-06-29 16:12:33  1561816724099|1    tech_screen_change_scores
# 2   2019-06-29 16:12:35  1561816724099|1  tech_screen_change_mainmenu
# 3   2019-06-29 16:13:57  1560695147351|1  tech_screen_change_mainmenu
# 4   2019-06-29 16:14:00  1560695147351|1           pregame_start_game
# 5   2019-06-29 16:14:00  1560695147351|1  tech_screen_change_gameplay
# 579 2019-06-29 16:27:07  1561816724099|1             game_board_click
#
# [580 rows x 3 columns]

# %%
#Run in your browser console
#localStorage.getItem('reboard_session_id')

# %%
result.to_csv('resul.csv')

# %%
PROJECT_PATH = 'retentioneering-tools'
from importlib.machinery import SourceFileLoader
somemodule = SourceFileLoader('retentioneering', 'retentioneering-tools/retentioneering/__init__.py').load_module()

# %%
from retentioneering import init_config
import pandas as pd

# %%
result[result.event_name =='tech_screen_change_scores']['user_pseudo_id'].nunique()
# Out:
# 1

# %%
init_config(
    experiments_folder='experiments', # folder for saving experiment results: graph visualization, heatmaps and etc.
    index_col='user_pseudo_id', # column by which we split users / sessions / whatever
    event_col='event_name', # column that describes event
    event_time_col='event_timestamp', # column that describes timestamp of event
    positive_target_event='tech_screen_change_scores', # name of positive target event
    negative_target_event='lost', # name of negative target event
    pos_target_definition={ # how to define positive event, e.g. empty means that add passed for whom was not 'lost'

    },
    neg_target_definition={ # how to define negative event, e.g. users who were inactive for 600 seconds.
        'time_limit': 600
    },
#     neg_target_definition={ # you also can define target event as list of other events
#         'event_list': ['lost']
#     }
)
# Out:
# retentioneering-tools/retentioneering/core/utils.py:53: UserWarning: registration of accessor <class 'retentioneering.core.utils.init_config.<locals>.RetentioneeringTrajectory'> under name 'trajectory' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class RetentioneeringTrajectory(BaseTrajectory):
# retentioneering-tools/retentioneering/core/utils.py:60: UserWarning: registration of accessor <class 'retentioneering.core.utils.init_config.<locals>.RetentioneeringDataset'> under name 'retention' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class RetentioneeringDataset(BaseDataset):

# %%
# data = pd.read_csv('examples/data/train.csv')
data = result.sort_values('event_timestamp')

# %%
result.event_name.unique()
# Out:
# array(['tech_screen_change_mainmenu', 'tech_screen_change_scores',
#        'pregame_start_game', 'tech_screen_change_gameplay',
#        'game_board_click', 'aftergame_winfinish',
#        'tech_screen_change_settings', 'pregame_change_settings',
#        'tech_screen_change_team', 'pregame_button_click'], dtype=object)

# %%
result = data.retention.prepare()

# %%
edgelist = data.retention.get_edgelist()
edgelist.head()
# Out:
#             event_name                   next_event  event_count
# 0  aftergame_winfinish             game_board_click          1.0
# 1  aftergame_winfinish           pregame_start_game          0.5
# 2  aftergame_winfinish  tech_screen_change_gameplay          0.5
# 3  aftergame_winfinish  tech_screen_change_mainmenu          0.5
# 4     game_board_click          aftergame_winfinish          3.0

# %%
edgelist = data.retention.get_edgelist(edge_col='user_pseudo_id', edge_attributes='users_nunique', norm=False)
edgelist.sort_values('users_nunique', ascending=False).head()
# Out:
#                      event_name           next_event  users_nunique
# 0           aftergame_winfinish     game_board_click              2
# 13  tech_screen_change_gameplay     game_board_click              2
# 4              game_board_click  aftergame_winfinish              2
# 5              game_board_click     game_board_click              2
# 15  tech_screen_change_mainmenu   pregame_start_game              2

# %%
data.retention.get_adjacency()
# Out:
#                              aftergame_winfinish  ...  tech_screen_change_team
# aftergame_winfinish                          0.0  ...                      0.0
# game_board_click                             3.0  ...                      0.0
# pregame_start_game                           0.0  ...                      0.0
# tech_screen_change_gameplay                  0.0  ...                      0.0
# tech_screen_change_mainmenu                  0.0  ...                      0.5
# pregame_button_click                         0.0  ...                      0.0
# pregame_change_settings                      0.0  ...                      0.0
# tech_screen_change_scores                    0.0  ...                      0.0
# tech_screen_change_settings                  0.0  ...                      0.0
# tech_screen_change_team                      0.0  ...                      0.0
#
# [10 rows x 10 columns]

# %%
data.retention.get_adjacency(edge_col='user_pseudo_id', edge_attributes='users_nunique', norm=False)
# Out:
#                              aftergame_winfinish  ...  tech_screen_change_team
# aftergame_winfinish                          0.0  ...                      0.0
# game_board_click                             2.0  ...                      0.0
# pregame_start_game                           0.0  ...                      0.0
# tech_screen_change_gameplay                  0.0  ...                      0.0
# tech_screen_change_mainmenu                  0.0  ...                      1.0
# pregame_button_click                         0.0  ...                      0.0
# pregame_change_settings                      0.0  ...                      0.0
# tech_screen_change_scores                    0.0  ...                      0.0
# tech_screen_change_settings                  0.0  ...                      0.0
# tech_screen_change_team                      0.0  ...                      0.0
#
# [10 rows x 10 columns]

# %%
data.retention.plot_graph(thresh=0.05, width=800, height=800)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="experiments/index_2019-06-29 16_21_34_136654.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
desc_table = data.retention.get_step_matrix(max_steps=30)

# %%
# create group filter based on target events
diff_filter = data.retention.create_filter()

# calculate difference table between two groups
diff_table = data.retention.get_step_matrix_difference(diff_filter, max_steps=30)

# %%
data.retention.get_adjacency()
# Out:
#                              aftergame_winfinish  ...  tech_screen_change_team
# aftergame_winfinish                          0.0  ...                      0.0
# game_board_click                             3.0  ...                      0.0
# pregame_start_game                           0.0  ...                      0.0
# tech_screen_change_gameplay                  0.0  ...                      0.0
# tech_screen_change_mainmenu                  0.0  ...                      0.5
# pregame_button_click                         0.0  ...                      0.0
# pregame_change_settings                      0.0  ...                      0.0
# tech_screen_change_scores                    0.0  ...                      0.0
# tech_screen_change_settings                  0.0  ...                      0.0
# tech_screen_change_team                      0.0  ...                      0.0
#
# [10 rows x 10 columns]

# %%
data.retention.learn_tsne(plot_type='targets');

# %%
data.retention.learn_tsne(perplexity=10, plot_type='targets', refit=True);

# %%
data.retention.get_clusters(n_clusters=8, plot_type='cluster_tsne', refit_cluster=True);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-8e33f2533650> in <module>
# ----> 1 data.retention.get_clusters(n_clusters=8, plot_type='cluster_tsne', refit_cluster=True);
#
# /content/retentioneering-tools/retentioneering/core/utils.py in get_clusters(self, plot_type, refit_cluster, **kwargs)
#     341             features = self.extract_features(**kwargs)
#     342         if not hasattr(self, 'clusters') or refit_cluster:
# --> 343             self.clusters = clustering.simple_cluster(features, **kwargs)
#     344             self._create_cluster_mapping(features.index.values)
#     345
#
# /content/retentioneering-tools/retentioneering/core/clustering.py in simple_cluster(data, **kwargs)
#      25     """
#      26     km = KMeans(random_state=0, **{i: j for i, j in kwargs.items() if i in __KMEANS_FILTER__})
# ---> 27     return km.fit_predict(data.values)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py in fit_predict(self, X, y, sample_weight)
#     993             Index of the cluster each sample belongs to.
#     994         """
# --> 995         return self.fit(X, sample_weight=sample_weight).labels_
#     996
#     997     def fit_transform(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     967                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     968                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 969                 return_n_iter=True)
#     970         return self
#     971
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     311     if _num_samples(X) < n_clusters:
#     312         raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
# --> 313             _num_samples(X), n_clusters))
#     314
#     315     tol = _tolerance(X, tol)
#
# ValueError: n_samples=2 should be >= n_clusters=8
